# %%
lista = ['amarilli','Verde','Rojo','Tomate','naranja']
lista.insert(0,'Primero')#Agregar segun la posicion a indicar
lista.append('Final')
print(lista)
# Out:
# ['Primero', 'amarilli', 'Verde', 'Rojo', 'Tomate', 'naranja', 'Final']

# %%
#inicio desde el 0
#Desde el final n+1
print(lista[0:4])
# Out:
# ['Primero', 'amarilli', 'Verde', 'Rojo']

# %%
print(lista[1:])#imprime desde el 1 en adelante
print(lista[:4])#imprimi desde el 0 hasta el 4
# Out:
# ['amarilli', 'Verde', 'Rojo', 'Tomate', 'naranja', 'Final']
# ['Primero', 'amarilli', 'Verde', 'Rojo']

# %%
import numpy as np
import pandas as pd
datos = np.array([[10,8],[7,6],[9,9]])#Creamos un nuevo dataset
pd.DataFrame(datos, index=['row1','row2','row3'],columns=
             ['col1','col2'])
# Out:
#       col1  col2
# row1    10     8
# row2     7     6
# row3     9     9

# %%
datos
# Out:
# array([[10,  8],
#        [ 7,  6],
#        [ 9,  9]])

# %%
df_examen = pd.read_csv('StudentsPerformance.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\VINICI~1\AppData\Local\Temp/ipykernel_24212/2059650885.py in <module>
# ----> 1 df_examen = pd.read_csv('StudentsPerformance.csv')
#
# NameError: name 'pd' is not defined

# %%
#Imprimi los ultimas 5 filas del dataframe 
df_examen.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#Accediendo a las filas y columas que tiene el dataframe
df_examen.shape
# Out:
# (1000, 8)

# %%
#Revisando el tipo de cada dato de la columna
df_examen.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Obteniendo valores estadistcos del dataframe
df_examen.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
x = len(df_examen['writing score'])
y = max(df_examen['reading score'])
z = min(df_examen['math score'])
print(x," ",y," ", " ",z)
# Out:
# 1000   100     0

# %%
#Seleccionando dos o mas columnas 
df_examen[['writing score','reading score']]
# Out:
#      writing score  reading score
# 0               74             72
# 1               88             90
# 2               93             95
# 3               44             57
# 4               75             78
# ..             ...            ...
# 995             95             99
# 996             55             55
# 997             65             71
# 998             77             78
# 999             86             86
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Agregando nueva columna

# %%
df_examen['Nueva columna'] = 70

# %%
df_examen.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Nueva columna
# 0             70
# 1             70
# 2             70
# 3             70
# 4             70

# %%
#import numpy
import numpy as np

# %%
#Creado datos en secuencia 
datos_arreglo = np.arange(0,1000)
#Agregamos los nuevos datos al arreglo
df_examen['Nueva columna2'] = datos_arreglo

# %%
df_examen.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Nueva columna  Nueva columna2
# 0             70               0
# 1             70               1
# 2             70               2
# ...

# %%
#crear datos aleatorios
datos_aleatorios = np.random.randint(1,100, size=1000)

# %%
#Se agrega los nuevos datos aleatorios
df_examen['datos aleatorios'] = datos_aleatorios

#prueba -> Para crear datos con decimales 
decimales = np.random.uniform(1,100, size=1000)

# %%
df_examen.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Nueva columna  Nueva columna2  datos aleatorios
# 0             70               0                64
# ...

# %% [markdown]
# # Opereaciones

# %% [markdown]
# ## Operaciones con columnas

# %%
#Sumamos todos los datos de la columna
df_examen['math score'].sum()
# Out:
# 66089

# %%
#Contamo todos los datos de la columna 
df_examen['math score'].count()
# Out:
# 1000

# %%
#Obtenemos el promedio de la columna
promedio = df_examen['math score'].mean()
max = df_examen['math score'].max()
min = df_examen['math score'].min()
print("mean: ",promedio, "max", max, "min", min )
# Out:
# mean:  66.089 max 100 min 0

# %%
#Obtenemos todos los datos con el promedio de la columna con describe
df_examen.describe()
# Out:
#        math score  reading score  writing score  Nueva columna  \
# count  1000.00000    1000.000000    1000.000000         1000.0
# mean     66.08900      69.169000      68.054000           70.0
# std      15.16308      14.600192      15.195657            0.0
# min       0.00000      17.000000      10.000000           70.0
# 25%      57.00000      59.000000      57.750000           70.0
# 50%      66.00000      70.000000      69.000000           70.0
# 75%      77.00000      79.000000      79.000000           70.0
# max     100.00000     100.000000     100.000000           70.0
#
#        Nueva columna2  datos aleatorios
# count     1000.000000       1000.000000
# mean       499.500000         49.947000
# std        288.819436         28.413016
# min          0.000000          1.000000
# 25%        249.750000         25.000000
# 50%        499.500000         49.000000
# 75%        749.250000         74.000000
# max        999.000000         99.000000

# %% [markdown]
# ## Operaciones con filas

# %%
#Se hace el calculo del promedio por filas
promedio = (df_examen['math score']	+ df_examen['reading score']+df_examen['writing score'])/3
#Redondeamos con el numerod de decimales que se quiere 
df_examen['Promedio total'] = promedio.round(2)

# %%
df_examen.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Nueva columna  Nueva columna2  datos aleatorios  Promedio total
# 0             70               0                64           72.67
# ...

# %% [markdown]
# # Value Counts

# %%
#Contar los elemento de la columna "gender"

len(df_examen['gender'])
# Out:
# 1000

# %%
#Contar lor elementos por categoria
df_examen['gender'].value_counts()
#Masculino
#Femenino
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#Obtener la frecuencia relaiva o %
df_examen['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
#Contar elementos de la columna por "categoria"
df_examen['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# # Formas de Ordenar el dataframe

# %%
df_examen.sort_values('math score', ascending=True)
#True -> De forma accedente 
#False -> De forma decendete
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
